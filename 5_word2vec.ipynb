# %% [markdown]
# Deep Learning
# =============
#
# Assignment 5
# ------------
#
# The goal of this assignment is to train a Word2Vec skip-gram model over [Text8](http://mattmahoney.net/dc/textdata) data.

# %%
# These are all the modules we'll be using later. Make sure you can import them
# before proceeding further.
# %matplotlib inline
from __future__ import print_function
import collections
import math
import numpy as np
import os
import random
import tensorflow as tf
import zipfile
from matplotlib import pylab
from six.moves import range
from six.moves.urllib.request import urlretrieve
from sklearn.manifold import TSNE

# %% [markdown]
# Download the data from the source website if necessary.

# %%
url = 'http://mattmahoney.net/dc/'

def maybe_download(filename, expected_bytes):
  """Download a file if not present, and make sure it's the right size."""
  if not os.path.exists(filename):
    filename, _ = urlretrieve(url + filename, filename)
  statinfo = os.stat(filename)
  if statinfo.st_size == expected_bytes:
    print('Found and verified %s' % filename)
  else:
    print(statinfo.st_size)
    raise Exception(
      'Failed to verify ' + filename + '. Can you get to it with a browser?')
  return filename

filename = maybe_download('text8.zip', 31344016)
# Out:
# Found and verified text8.zip

# %% [markdown]
# Read the data into a string.

# %%
def read_data(filename):
  """Extract the first file enclosed in a zip file as a list of words"""
  with zipfile.ZipFile(filename) as f:
    data = tf.compat.as_str(f.read(f.namelist()[0])).split()
  return data
  
words = read_data(filename)
print('Data size %d' % len(words))
# Out:
# Data size 17005207

# %% [markdown]
# Build the dictionary and replace rare words with UNK token.

# %%
vocabulary_size = 50000

def build_dataset(words):
  count = [['UNK', -1]]
  count.extend(collections.Counter(words).most_common(vocabulary_size - 1))
#   print(count)

  dictionary = dict()
  for word, _ in count:
    dictionary[word] = len(dictionary)
#   print(dictionary)

  data = list()
  unk_count = 0
  for word in words:
    if word in dictionary:
      index = dictionary[word]
    else:
      index = 0  # dictionary['UNK']
      unk_count = unk_count + 1
    data.append(index)
  count[0][1] = unk_count
  reverse_dictionary = dict(zip(dictionary.values(), dictionary.keys())) 
  return data, count, dictionary, reverse_dictionary

data, count, dictionary, reverse_dictionary = build_dataset(words)

print('Most common words (+UNK)', count[:5])
print('Sample data', data[:10])
del words  # Hint to reduce memory.
# Out:
# Most common words (+UNK) [['UNK', 418391], ('the', 1061396), ('of', 593677), ('and', 416629), ('one', 411764)]
# Sample data [5242, 3081, 12, 6, 195, 2, 3137, 46, 59, 156]

# %% [markdown]
# Function to generate a training batch for the skip-gram model.

# %%
data_index = 0

def generate_batch(batch_size, num_skips, skip_window):
  global data_index
  assert batch_size % num_skips == 0
  assert num_skips <= 2 * skip_window
  batch = np.ndarray(shape=(batch_size), dtype=np.int32)
  labels = np.ndarray(shape=(batch_size, 1), dtype=np.int32)
  
  span = 2 * skip_window + 1 # [ skip_window target skip_window ]
  buffer = collections.deque(maxlen=span)
  for _ in range(span):
    buffer.append(data[data_index])
#     print(buffer)
#     print(data[data_index])
#     print(data_index)
    data_index = (data_index + 1) % len(data)
  for i in range(batch_size // num_skips):
    target = skip_window  # target label at the center of the buffer
    targets_to_avoid = [ skip_window ]
    for j in range(num_skips):
      while target in targets_to_avoid:
        target = random.randint(0, span - 1)
      targets_to_avoid.append(target)
      batch[i * num_skips + j] = buffer[skip_window]
      labels[i * num_skips + j, 0] = buffer[target]
    buffer.append(data[data_index])
    data_index = (data_index + 1) % len(data)
  return batch, labels

print('data:', [reverse_dictionary[di] for di in data[:8]])

for num_skips, skip_window in [(2, 1), (4, 2)]:
    data_index = 0
    batch, labels = generate_batch(batch_size=8, num_skips=num_skips, skip_window=skip_window)
    print('\nwith num_skips = %d and skip_window = %d:' % (num_skips, skip_window))
    print('    batch:', [reverse_dictionary[bi] for bi in batch])
    print('    labels:', [reverse_dictionary[li] for li in labels.reshape(8)])
# Out:
# data: ['anarchism', 'originated', 'as', 'a', 'term', 'of', 'abuse', 'first']
#
# with num_skips = 2 and skip_window = 1:
#     batch: ['originated', 'originated', 'as', 'as', 'a', 'a', 'term', 'term']
#     labels: ['anarchism', 'as', 'originated', 'a', 'as', 'term', 'of', 'a']
#
# with num_skips = 4 and skip_window = 2:
#     batch: ['as', 'as', 'as', 'as', 'a', 'a', 'a', 'a']
#     labels: ['term', 'originated', 'a', 'anarchism', 'originated', 'of', 'as', 'term']

# %% [markdown]
# Train a skip-gram model.

# %%
batch_size = 128
embedding_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
# We pick a random validation set to sample nearest neighbors. here we limit the
# validation samples to the words that have a low numeric ID, which by
# construction are also the most frequent. 
valid_size = 16 # Random set of words to evaluate similarity on.
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_examples = np.array(random.sample(range(valid_window), valid_size))
print(valid_examples)
num_sampled = 64 # Number of negative examples to sample.

graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

  # Input data.
  train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
  train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
  valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
  
  # Variables.
  embeddings = tf.Variable(
    tf.random_uniform([vocabulary_size, embedding_size], -1.0, 1.0))
  softmax_weights = tf.Variable(
    tf.truncated_normal([vocabulary_size, embedding_size],
                         stddev=1.0 / math.sqrt(embedding_size)))
  softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
  
  # Model.
  # Look up embeddings for inputs.
  embed = tf.nn.embedding_lookup(embeddings, train_dataset)
  # Compute the softmax loss, using a sample of the negative labels each time.
  loss = tf.reduce_mean(
    tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                               train_labels, num_sampled, vocabulary_size))

  # Optimizer.
  # Note: The optimizer will optimize the softmax_weights AND the embeddings.
  # This is because the embeddings are defined as a variable quantity and the
  # optimizer's `minimize` method will by default modify all variable quantities 
  # that contribute to the tensor it is passed.
  # See docs on `tf.train.Optimizer.minimize()` for more details.
  optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
  
  # Compute the similarity between minibatch examples and all embeddings.
  # We use the cosine distance:
  norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
  normalized_embeddings = embeddings / norm
  valid_embeddings = tf.nn.embedding_lookup(
    normalized_embeddings, valid_dataset)
  similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))
# Out:
# [34 80 75  3  0 84 37 99 92 43 51 65 70  7 32 35]

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
  tf.initialize_all_variables().run()
  print('Initialized')
  average_loss = 0
  for step in range(num_steps):
    batch_data, batch_labels = generate_batch(
      batch_size, num_skips, skip_window)
#     print(batch_data)
    feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
    _, l = session.run([optimizer, loss], feed_dict=feed_dict)
    average_loss += l
    if step % 2000 == 0:
      if step > 0:
        average_loss = average_loss / 2000
      # The average loss is an estimate of the loss over the last 2000 batches.
      print('Average loss at step %d: %f' % (step, average_loss))
      average_loss = 0
    # note that this is expensive (~20% slowdown if computed every 500 steps)
    if step % 10000 == 0:
      sim = similarity.eval()
      for i in range(valid_size):
        valid_word = reverse_dictionary[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
          close_word = reverse_dictionary[nearest[k]]
          log = '%s %s,' % (log, close_word)
        print(log)
  final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.853670
# Nearest to which: assassins, steroid, registry, kissed, catalans, keiretsu, appointing, offenders,
# Nearest to over: colonialism, nigsberg, remedial, fellini, tudes, cleaned, characterization, ppt,
# Nearest to d: intakes, materials, blackfoot, liquids, cataclysm, unamended, corvinus, cacm,
# Nearest to and: abyss, flamboyant, presumably, clowns, hagar, bazaar, meir, minute,
# Nearest to UNK: adventist, trails, nationality, suggestion, carnal, hol, ma, mpls,
# Nearest to war: wired, geothermal, became, catullus, promptly, humankind, airframes, spectra,
# Nearest to also: angels, alcoholism, stratofortress, tattoos, ton, blackhawks, voiceless, freezing,
# Nearest to while: predicts, orfeo, bees, cabinet, underlies, urged, demeaning, bolshevik,
# Nearest to system: maxwell, inclusions, chippewa, ansar, resolute, lucy, sir, specials,
# Nearest to other: circumnavigation, extracting, basayev, quartering, liners, bacillus, panic, arrive,
# Nearest to more: killer, reid, marine, ryan, galina, canis, elite, clarinetists,
# Nearest to time: chen, ayling, cones, futurists, cromarty, abjads, salvator, delightful,
# Nearest to than: gokturk, tyres, highlander, vh, shooters, diophantus, restraint, sherman,
# Nearest to to: shasta, kerman, exaggerating, crookes, outdated, unintentional, distracted, acosta,
# Nearest to be: droppings, turkic, massacred, gilbertese, cobain, carmel, adler, holley,
# Nearest to at: conquerors, gradient, spenser, fulcher, brightness, unequivocally, overtly, cumings,
# Average loss at step 2000: 4.354483
# Average loss at step 4000: 3.860829
# Average loss at step 6000: 3.783567
# Average loss at step 8000: 3.683371
# Average loss at step 10000: 3.617536
# Nearest to which: this, that, there, also, it, doe, and, neutral,
# Nearest to over: trading, colonialism, nigsberg, ligaments, fellini, lindy, speaking, tudes,
# Nearest to d: intakes, begged, b, minimally, materials, bissette, accessed, liquids,
# Nearest to and: or, in, gam, of, which, for, ciconiiformes, including,
# Nearest to UNK: forcefully, tightly, syncopated, branko, bear, flavorings, torquay, overdrive,
# Nearest to war: entablature, refuse, starcraft, malts, humankind, concluding, julio, draconis,
# Nearest to also: angels, it, which, there, sometimes, he, recourse, incompatible,
# Nearest to while: reservations, cabinet, offshore, predicts, elections, showed, nimh, underlies,
# Nearest to system: lucy, panicked, license, chippewa, inclusions, specials, greatly, imprinting,
# Nearest to other: some, many, plants, extracting, forays, niue, cafes, organist,
# Nearest to more: masculism, reid, resolved, marine, galina, ryan, oncology, originals,
# Nearest to time: although, cones, abjads, contents, chen, danny, shangri, whitby,
# Nearest to than: tyres, gokturk, darkest, wooden, sherman, pulmonic, oregon, trapdoor,
# Nearest to to: distracted, would, not, supremely, joint, rajiv, saginaw, dominoes,
# Nearest to be: have, flatter, was, noticing, is, droppings, by, mix,
# Nearest to at: conquerors, in, on, egyptian, carthaginian, overshadowed, kneeling, ancestry,
# Average loss at step 12000: 3.606593
# Average loss at step 14000: 3.572609
# Average loss at step 16000: 3.404431
# Average loss at step 18000: 3.451468
# Average loss at step 20000: 3.541999
# Nearest to which: that, this, also, there, who, it, doe, frequently,
# Nearest to over: trading, ligaments, unproven, colonialism, utilization, donaghy, nigsberg, coolant,
# Nearest to d: b, begged, intakes, accessed, wrangling, minimally, admirable, functionalists,
# Nearest to and: or, including, but, which, gam, with, dimona, in,
# Nearest to UNK: termed, forcefully, potion, xenosaga, overdrive, nitride, inspiring, judean,
# Nearest to war: entablature, refuse, humankind, polytheism, draconis, impacted, concluding, wired,
# Nearest to also: which, angels, now, who, sometimes, often, always, liv,
# Nearest to while: reservations, cabinet, under, predicts, nimh, offshore, placing, newtonian,
# Nearest to system: lucy, panicked, greatly, imprinting, appreciation, complex, license, waged,
# Nearest to other: many, some, various, plants, these, destroying, pamphilus, different,
# Nearest to more: masculism, less, reid, not, most, aykroyd, cena, nested,
# Nearest to time: whitby, cones, danny, although, bases, contents, hydrolysis, shangri,
# Nearest to than: or, darkest, sherman, tyres, trapdoor, wooden, senatus, sphinx,
# Nearest to to: would, outdated, distracted, may, rolle, prefers, saginaw, should,
# Nearest to be: have, refer, been, was, were, is, ask, flatter,
# Nearest to at: in, on, with, overshadowed, from, savior, melancholia, after,
# Average loss at step 22000: 3.502796
# Average loss at step 24000: 3.493179
# Average loss at step 26000: 3.477443
# Average loss at step 28000: 3.478431
# Average loss at step 30000: 3.505698
# Nearest to which: this, that, also, it, what, actually, who, but,
# Nearest to over: unproven, through, prattica, trading, couture, donaghy, utilization, brackets,
# Nearest to d: b, begged, accessed, intakes, aortic, recruit, denoting, mayer,
# Nearest to and: or, but, in, pr, who, of, ackermann, priam,
# Nearest to UNK: et, bianca, potion, decrypt, voices, mp, titled, shaw,
# Nearest to war: entablature, impacted, polytheism, humankind, asymptotic, nmt, dasyprocta, draconis,
# Nearest to also: often, which, now, who, actually, sometimes, always, there,
# Nearest to while: when, under, cabinet, newtonian, glasnevin, says, gave, livingstone,
# Nearest to system: panicked, imprinting, systems, spiral, greatly, spends, lucy, inclusions,
# Nearest to other: various, these, some, destroying, many, plants, such, different,
# Nearest to more: masculism, less, most, aykroyd, rather, winger, reid, very,
# Nearest to time: whitby, year, hydrolysis, cones, danny, venn, securely, delightful,
# Nearest to than: wooden, darkest, sherman, tyres, much, emigrated, secularism, or,
# Nearest to to: would, distracted, joint, should, unauthorized, stressed, outdated, can,
# Nearest to be: have, is, been, were, are, refer, being, was,
# Nearest to at: in, after, microwaves, ghanaian, conquerors, on, centralizing, cooperatively,
# Average loss at step 32000: 3.498373
# Average loss at step 34000: 3.489797
# Average loss at step 36000: 3.450374
# Average loss at step 38000: 3.300839
# Average loss at step 40000: 3.423894
# Nearest to which: that, this, also, usually, actually, who, it, these,
# Nearest to over: through, prattica, utilization, reused, unproven, ligaments, from, off,
# Nearest to d: b, begged, accessed, intakes, UNK, paces, corvinus, rupture,
# Nearest to and: or, but, shelled, transhumanism, in, dimona, s, e,
# Nearest to UNK: b, mysticeti, d, bogged, waffen, j, o, adaptable,
# Nearest to war: entablature, polytheism, impacted, predictably, dasyprocta, defending, nmt, asymptotic,
# Nearest to also: which, often, sometimes, usually, always, now, still, who,
# Nearest to while: when, says, but, offshore, contractor, newtonian, dalit, welding,
# Nearest to system: systems, panicked, digit, imprinting, alem, waged, dozens, novgorod,
# Nearest to other: different, various, destroying, inaccuracies, brant, ruby, many, some,
# Nearest to more: less, masculism, most, very, aykroyd, rather, not, cheaper,
# Nearest to time: year, way, whitby, securely, danny, roper, chen, hydrolysis,
# Nearest to than: or, wooden, much, darkest, secularism, barefoot, sloop, emigrated,
# Nearest to to: would, culver, catalogued, will, unauthorized, saginaw, distracted, braun,
# Nearest to be: been, have, being, refer, were, is, are, ask,
# Nearest to at: on, coaches, overshadowed, in, cooperatively, sockets, laurentiis, microwaves,
# Average loss at step 42000: 3.433499
# Average loss at step 44000: 3.453689
# Average loss at step 46000: 3.450277
# Average loss at step 48000: 3.352692
# Average loss at step 50000: 3.385061
# Nearest to which: that, this, what, actually, who, also, these, but,
# Nearest to over: through, off, into, platform, coolant, on, deuteronomy, about,
# Nearest to d: b, accessed, begged, paces, j, e, intakes, corvinus,
# Nearest to and: or, but, of, while, including, s, like, from,
# Nearest to UNK: ligurian, classifying, condensation, carl, corvus, j, presumptive, beos,
# Nearest to war: entablature, polytheism, impacted, asymptotic, dasyprocta, predictably, passion, roofed,
# Nearest to also: often, always, usually, which, now, still, sometimes, actually,
# Nearest to while: when, however, but, although, after, says, though, welding,
# Nearest to system: systems, panicked, digit, novgorod, malone, alem, profiles, dozens,
# Nearest to other: various, different, destroying, inaccuracies, these, many, some, fewer,
# Nearest to more: less, most, masculism, very, longer, better, winger, aykroyd,
# Nearest to time: year, way, hitter, whitby, period, unconstitutional, rabid, shangri,
# Nearest to than: wooden, darkest, or, barefoot, much, organists, secularism, chopping,
# Nearest to to: should, could, would, can, will, outdated, may, across,
# Nearest to be: have, refer, been, being, was, is, were, become,
# Nearest to at: during, on, emphatic, from, overshadowed, auden, towers, rosh,
# Average loss at step 52000: 3.439852
# Average loss at step 54000: 3.428224
# Average loss at step 56000: 3.437996
# Average loss at step 58000: 3.393638
# Average loss at step 60000: 3.392791
# Nearest to which: that, this, what, these, actually, also, who, it,
# Nearest to over: through, off, into, about, platform, within, deuteronomy, unproven,
# Nearest to d: b, accessed, ogilvie, t, begged, paces, stanley, corvinus,
# Nearest to and: or, but, including, in, thayer, like, although, for,
# Nearest to UNK: intelligent, elisabeth, emigrant, professionally, sidespin, overdrive, mohawk, midlands,
# Nearest to war: impacted, entablature, dasyprocta, asymptotic, polytheism, misgivings, predictably, wars,
# Nearest to also: now, often, still, never, usually, always, sometimes, frequently,
# Nearest to while: although, when, but, after, though, however, were, says,
# Nearest to system: systems, panicked, digit, malone, goal, base, program, fondation,
# Nearest to other: various, different, destroying, inaccuracies, many, including, food, absorptive,
# Nearest to more: less, masculism, very, most, longer, better, rather, smaller,
# Nearest to time: year, way, unconstitutional, hitter, rabid, period, roper, venn,
# Nearest to than: wooden, or, much, barefoot, darkest, but, legislators, chopping,
# Nearest to to: xxvi, outdated, may, would, sheltered, futurama, monstrous, might,
# Nearest to be: been, refer, being, was, are, helaman, were, historiographical,
# Nearest to at: seismic, in, during, overshadowed, cooperatively, kalamazoo, bogside, kneeling,
# Average loss at step 62000: 3.241297
# Average loss at step 64000: 3.255498
# Average loss at step 66000: 3.403565
# Average loss at step 68000: 3.392666
# Average loss at step 70000: 3.358851
# Nearest to which: that, this, what, actually, also, usually, but, these,
# Nearest to over: through, off, about, productive, unproven, coyne, deuteronomy, platform,
# Nearest to d: b, accessed, begged, paces, n, ogilvie, j, stanley,
# Nearest to and: or, but, runoff, while, including, like, tyndale, of,
# Nearest to UNK: mr, shavuot, j, misinformation, mangaverse, undercarriage, elisabeth, intelligent,
# Nearest to war: wars, impacted, entablature, asymptotic, misgivings, polytheism, dasyprocta, antiques,
# Nearest to also: still, now, often, usually, which, never, sometimes, actually,
# Nearest to while: although, when, however, though, but, where, before, including,
# Nearest to system: systems, panicked, digit, program, process, profiles, bloomfield, dozens,
# Nearest to other: different, some, various, destroying, fewer, many, food, jet,
# Nearest to more: less, most, very, masculism, better, longer, aykroyd, winger,
# Nearest to time: year, way, unconstitutional, hitter, unloaded, process, rabid, period,
# Nearest to than: wooden, barefoot, or, darkest, much, legislators, organists, no,
# Nearest to to: would, will, must, could, xxvi, should, recalcitrant, distracted,
# Nearest to be: been, being, were, become, refer, is, helaman, ask,
# Nearest to at: during, seismic, bogside, overshadowed, kalamazoo, belarusians, cooperatively, audrey,
# Average loss at step 72000: 3.372661
# Average loss at step 74000: 3.346971
# Average loss at step 76000: 3.318582
# Average loss at step 78000: 3.351970
# Average loss at step 80000: 3.374377
# Nearest to which: this, that, usually, actually, what, also, frequently, who,
# Nearest to over: off, through, about, within, around, into, coyne, convicts,
# Nearest to d: b, accessed, paces, externalism, luz, ogilvie, nilo, vapour,
# Nearest to and: or, but, silenced, while, rooming, mortals, hooves, including,
# Nearest to UNK: ami, benevento, et, j, icp, ferguson, gunnar, jones,
# Nearest to war: wars, impacted, asymptotic, polytheism, entablature, misgivings, rewarding, predictably,
# Nearest to also: now, often, still, never, sometimes, frequently, which, usually,
# Nearest to while: although, though, when, but, however, before, after, says,
# Nearest to system: systems, panicked, program, digit, process, alem, bloomfield, fondation,
# Nearest to other: various, different, many, destroying, fewer, some, others, especially,
# Nearest to more: less, masculism, very, most, aykroyd, winger, longer, better,
# Nearest to time: year, unconstitutional, whitby, way, unloaded, hitter, venn, season,
# Nearest to than: wooden, much, or, legislators, barefoot, far, foiled, emigrated,
# Nearest to to: unauthorized, would, will, outdated, syndicalists, into, may, stressed,
# Nearest to be: been, have, being, become, refer, is, was, are,
# Nearest to at: in, on, seismic, overshadowed, after, audrey, cricketing, around,
# Average loss at step 82000: 3.405472
# Average loss at step 84000: 3.409624
# Average loss at step 86000: 3.391153
# Average loss at step 88000: 3.347516
# Average loss at step 90000: 3.371279
# Nearest to which: this, that, actually, also, what, usually, often, both,
# Nearest to over: off, through, platform, around, within, productive, about, against,
# Nearest to d: b, accessed, t, externalism, keats, paces, michael, czar,
# Nearest to and: or, but, including, while, by, thug, rooming, chungcheong,
# Nearest to UNK: inspiring, sidespin, kilgore, ix, schlesinger, landings, esp, antiretroviral,
# Nearest to war: wars, impacted, asymptotic, misgivings, entablature, sica, polytheism, intellectual,
# Nearest to also: often, now, which, still, sometimes, never, frequently, usually,
# Nearest to while: although, though, when, before, during, after, however, but,
# Nearest to system: systems, process, program, alem, panicked, digit, fondation, beech,
# Nearest to other: various, destroying, fewer, elan, different, regulatory, oft, extensionality,
# Nearest to more: less, masculism, very, most, longer, better, cheaper, highly,
# Nearest to time: year, unconstitutional, whitby, season, period, rabid, venn, hitter,
# Nearest to than: wooden, barefoot, legislators, underline, secularism, emigrated, or, much,
# Nearest to to: would, towards, will, unauthorized, against, distracted, saginaw, xxvi,
# Nearest to be: been, being, become, was, have, is, were, refer,
# Nearest to at: during, sockets, on, under, cricketing, after, in, collectivized,
# Average loss at step 92000: 3.394873
# Average loss at step 94000: 3.254184
# Average loss at step 96000: 3.361203
# Average loss at step 98000: 3.240605
# Average loss at step 100000: 3.354912
# Nearest to which: that, this, usually, what, actually, these, typically, often,
# Nearest to over: off, through, platform, against, medley, within, considerable, around,
# Nearest to d: b, michael, accessed, x, c, alonso, stephen, gregor,
# Nearest to and: or, but, while, however, including, although, who, of,
# Nearest to UNK: extinct, aussie, niv, bleak, titular, minivans, termed, canaries,
# Nearest to war: wars, impacted, asymptotic, corps, sica, embellished, entablature, factbook,
# Nearest to also: now, never, sometimes, still, often, actually, frequently, usually,
# Nearest to while: although, when, though, where, and, but, before, however,
# Nearest to system: systems, process, bloomfield, program, alem, panicked, fondation, device,
# Nearest to other: various, destroying, fewer, elan, others, extensionality, caterpillars, different,
# Nearest to more: less, very, most, masculism, cheaper, longer, packages, larger,
# Nearest to time: year, way, unconstitutional, whitby, debate, rabid, season, period,
# Nearest to than: or, much, barefoot, secularism, emigrated, wooden, legislators, darkest,
# Nearest to to: could, will, would, should, unauthorized, can, stressed, and,
# Nearest to be: been, refer, being, have, is, are, were, become,
# Nearest to at: during, on, ghanaian, in, chicxulub, after, seismic, arbroath,

# %%
num_points = 400

tsne = TSNE(perplexity=30, n_components=2, init='pca', n_iter=5000)
two_d_embeddings = tsne.fit_transform(final_embeddings[1:num_points+1, :])

# %%
def plot(embeddings, labels):
  assert embeddings.shape[0] >= len(labels), 'More labels than embeddings'
  pylab.figure(figsize=(15,15))  # in inches
  for i, label in enumerate(labels):
    x, y = embeddings[i,:]
    pylab.scatter(x, y)
    pylab.annotate(label, xy=(x, y), xytext=(5, 2), textcoords='offset points',
                   ha='right', va='bottom')
  pylab.show()

words = [reverse_dictionary[i] for i in range(1, num_points+1)]
plot(two_d_embeddings, words)
# Out:
# /usr/lib/python3/dist-packages/matplotlib/collections.py:571: FutureWarning: elementwise comparison failed; returning scalar instead, but in the future will perform elementwise comparison
#   if self._edgecolors == str('face'):

# %% [markdown]
# ---
#
# Problem
# -------
#
# An alternative to skip-gram is another Word2Vec model called [CBOW](http://arxiv.org/abs/1301.3781) (Continuous Bag of Words). In the CBOW model, instead of predicting a context word from a word vector, you predict a word from the sum of all the word vectors in its context. Implement and evaluate a CBOW model trained on the text8 dataset.
#
# ---

# %%
# In this method instead of passing a single word vector and predicting a context word, we took context of 3-words
# averaged it and passed as input and predicted the context words, in here a single word matching the context of 
# 3-words

batch_size = 128
hidden_size = 128 # Dimension of the embedding vector.
skip_window = 1 # How many words to consider left and right.
num_skips = 2 # How many times to reuse an input to generate a label.
context_size = 3

valid_size = 16 * context_size # Random set of words to evaluate similarity on. 
                                   
valid_window = 100 # Only pick dev samples in the head of the distribution.
valid_words = np.array(random.sample(range(valid_window), valid_size)) # Generate valid_size random numbers 
                                                                          # in range(valid_window) i.e between 0-99.
                                                                          # This is done to randomly pick examples.

num_sampled = 64 # Number of negative examples to sample.

# a single element of this array is average context of 3 consecutive words in the valid_words list
# Average up 3 successive word's indices in the set so as to obtain the context of 3 words together.
# Eg: If context is x1,x2,x3 where each is a 1-hot word vector then input to our model should be (x1+x2+x3)/3
valid_context = np.int32([np.sum(valid_words[i*context_size : i*context_size+context_size])/context_size for i in range(16)]    )


graph = tf.Graph()

with graph.as_default(), tf.device('/cpu:0'):

    # Input data.
    train_dataset = tf.placeholder(tf.int32, shape=[batch_size])
    train_labels = tf.placeholder(tf.int32, shape=[batch_size, 1])
    valid_dataset = tf.constant(valid_words, dtype=tf.int32)
    valid_dataset_context = tf.constant(valid_context, dtype=tf.int32)
    
    # Variables.
    embeddings = tf.Variable(
        tf.random_uniform([vocabulary_size, hidden_size], -1.0, 1.0))
    softmax_weights = tf.Variable(
        tf.truncated_normal([vocabulary_size, hidden_size],
                                                 stddev=1.0 / math.sqrt(hidden_size)))
    softmax_biases = tf.Variable(tf.zeros([vocabulary_size]))
    
    # Model.
    # Look up embeddings for inputs.
    embed = tf.nn.embedding_lookup(embeddings, train_dataset)
    # Compute the softmax loss, using a sample of the negative labels each time.
    loss = tf.reduce_mean(
        tf.nn.sampled_softmax_loss(softmax_weights, softmax_biases, embed,
                                                             train_labels, num_sampled, vocabulary_size))

    # Optimizer.
    # Note: The optimizer will optimize the softmax_weights AND the embeddings.
    # This is because the embeddings are defined as a variable quantity and the
    # optimizer's `minimize` method will by default modify all variable quantities 
    # that contribute to the tensor it is passed.
    # See docs on `tf.train.Optimizer.minimize()` for more details.
    optimizer = tf.train.AdagradOptimizer(1.0).minimize(loss)
    
    norm = tf.sqrt(tf.reduce_sum(tf.square(embeddings), 1, keep_dims=True))
    normalized_embeddings = embeddings / norm 
    valid_embeddings = tf.nn.embedding_lookup(normalized_embeddings, valid_dataset)
    
    similarity = tf.matmul(valid_embeddings, tf.transpose(normalized_embeddings))

# %%
num_steps = 100001

with tf.Session(graph=graph) as session:
    tf.initialize_all_variables().run()
    print('Initialized')
    average_loss = 0
    for step in range(num_steps):
        batch_data, batch_labels = generate_batch(
            batch_size, num_skips, skip_window)
        feed_dict = {train_dataset : batch_data, train_labels : batch_labels}
        _, l = session.run([optimizer, loss], feed_dict=feed_dict)
        average_loss += l
        if step % 2000 == 0:
            if step > 0:
                average_loss = average_loss / 2000
            # average loss over the last 2000 steps/batches
            print('Average loss at step %d: %f' % (step, average_loss))
            average_loss = 0
        # note that this is expensive (~20% slowdown if computed every 500 steps)
        if step % 10000 == 0:
            sim = similarity.eval()
            for i in range(16):
                valid_context = [reverse_dictionary[valid_examples_allwords[i*words_in_context + j]] for j in range(words_in_context)]
                top_k = 1 # number of nearest neighbors (Pick only 1 nearest neighbour)
                nearest = (-sim[i, :]).argsort()[1:top_k+1]
                log = 'Nearest to %s:' % valid_context
                for k in range(top_k):
                    close_word = reverse_dictionary[nearest[k]]
                    log = '%s %s,' % (log, close_word)
                print(log)
    final_embeddings = normalized_embeddings.eval()
# Out:
# Initialized
# Average loss at step 0: 7.232818
# Nearest to ['time', 'some', 'who']: properties,
# Nearest to ['only', 'see', 'th']: bellows,
# Nearest to ['of', 'will', 'is']: encroachment,
# Nearest to ['four', 'states', 'called']: kyle,
# Nearest to ['often', 'for', 'and']: vaduz,
# Nearest to ['his', 'history', 'at']: aberdeenshire,
# Nearest to ['been', 'may', 'to']: barrington,
# Nearest to ['are', 'into', 'there']: praetorians,
# Nearest to ['he', 'so', 'these']: antigonus,
# Nearest to ['their', 'new', 'years']: sidney,
# Nearest to ['united', 'all', 'on']: cosine,
# Nearest to ['six', 'over', 'its']: azov,
# Nearest to ['about', 'in', 'would']: timbuktu,
# Nearest to ['they', 'three', 'as']: copying,
# Nearest to ['known', 'state', 'if']: drexler,
# Nearest to ['it', 's', 'during']: mena,
# Average loss at step 2000: 4.298248
# Average loss at step 4000: 3.850569
# Average loss at step 6000: 3.749608
# Average loss at step 8000: 3.731441
# Average loss at step 10000: 3.667171
# Nearest to ['time', 'some', 'who']: four,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: main,
# Nearest to ['four', 'states', 'called']: pens,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: spokes,
# Nearest to ['been', 'may', 'to']: on,
# Nearest to ['are', 'into', 'there']: praetorians,
# Nearest to ['he', 'so', 'these']: second,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: it,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: nine,
# Nearest to ['known', 'state', 'if']: four,
# Nearest to ['it', 's', 'during']: before,
# Average loss at step 12000: 3.671157
# Average loss at step 14000: 3.534469
# Average loss at step 16000: 3.434947
# Average loss at step 18000: 3.570470
# Average loss at step 20000: 3.532837
# Nearest to ['time', 'some', 'who']: four,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: unbridled,
# Nearest to ['four', 'states', 'called']: mohiam,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: jeong,
# Nearest to ['been', 'may', 'to']: on,
# Nearest to ['are', 'into', 'there']: handbooks,
# Nearest to ['he', 'so', 'these']: second,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: they,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: nine,
# Nearest to ['known', 'state', 'if']: eight,
# Nearest to ['it', 's', 'during']: before,
# Average loss at step 22000: 3.514894
# Average loss at step 24000: 3.524713
# Average loss at step 26000: 3.536279
# Average loss at step 28000: 3.478832
# Average loss at step 30000: 3.457391
# Nearest to ['time', 'some', 'who']: five,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: in,
# Nearest to ['four', 'states', 'called']: amusing,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: jeong,
# Nearest to ['been', 'may', 'to']: on,
# Nearest to ['are', 'into', 'there']: handbooks,
# Nearest to ['he', 'so', 'these']: second,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: they,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: six,
# Nearest to ['known', 'state', 'if']: eight,
# Nearest to ['it', 's', 'during']: before,
# Average loss at step 32000: 3.178575
# Average loss at step 34000: 3.357459
# Average loss at step 36000: 3.440512
# Average loss at step 38000: 3.310112
# Average loss at step 40000: 3.414952
# Nearest to ['time', 'some', 'who']: frustrating,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: in,
# Nearest to ['four', 'states', 'called']: women,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: jeong,
# Nearest to ['been', 'may', 'to']: at,
# Nearest to ['are', 'into', 'there']: d,
# Nearest to ['he', 'so', 'these']: second,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: they,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: seven,
# Nearest to ['known', 'state', 'if']: eight,
# Nearest to ['it', 's', 'during']: before,
# Average loss at step 42000: 3.489235
# Average loss at step 44000: 3.436520
# Average loss at step 46000: 3.348307
# Average loss at step 48000: 3.308006
# Average loss at step 50000: 3.423703
# Nearest to ['time', 'some', 'who']: st,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: original,
# Nearest to ['four', 'states', 'called']: women,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: systems,
# Nearest to ['been', 'may', 'to']: during,
# Nearest to ['are', 'into', 'there']: d,
# Nearest to ['he', 'so', 'these']: second,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: they,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: nine,
# Nearest to ['known', 'state', 'if']: eight,
# Nearest to ['it', 's', 'during']: before,
# Average loss at step 52000: 3.454654
# Average loss at step 54000: 3.456881
# Average loss at step 56000: 3.393193
# Average loss at step 58000: 3.355406
# Average loss at step 60000: 3.396396
# Nearest to ['time', 'some', 'who']: st,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: including,
# Nearest to ['four', 'states', 'called']: children,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: systems,
# Nearest to ['been', 'may', 'to']: during,
# Nearest to ['are', 'into', 'there']: d,
# Nearest to ['he', 'so', 'these']: last,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: it,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: nine,
# Nearest to ['known', 'state', 'if']: nine,
# Nearest to ['it', 's', 'during']: before,
# Average loss at step 62000: 3.334831
# Average loss at step 64000: 3.364191
# Average loss at step 66000: 3.346178
# Average loss at step 68000: 3.316209
# Average loss at step 70000: 3.260373
# Nearest to ['time', 'some', 'who']: three,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: including,
# Nearest to ['four', 'states', 'called']: children,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: systems,
# Nearest to ['been', 'may', 'to']: during,
# Nearest to ['are', 'into', 'there']: d,
# Nearest to ['he', 'so', 'these']: last,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: they,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: nine,
# Nearest to ['known', 'state', 'if']: six,
# Nearest to ['it', 's', 'during']: before,
# Average loss at step 72000: 3.285541
# Average loss at step 74000: 3.355031
# Average loss at step 76000: 3.339094
# Average loss at step 78000: 3.323488
# Average loss at step 80000: 3.337852
# Nearest to ['time', 'some', 'who']: st,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: in,
# Nearest to ['four', 'states', 'called']: children,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: systems,
# Nearest to ['been', 'may', 'to']: within,
# Nearest to ['are', 'into', 'there']: d,
# Nearest to ['he', 'so', 'these']: last,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: they,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: nine,
# Nearest to ['known', 'state', 'if']: eight,
# Nearest to ['it', 's', 'during']: before,
# Average loss at step 82000: 3.332198
# Average loss at step 84000: 3.386261
# Average loss at step 86000: 3.358386
# Average loss at step 88000: 3.359125
# Average loss at step 90000: 3.313289
# Nearest to ['time', 'some', 'who']: bc,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: for,
# Nearest to ['four', 'states', 'called']: children,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: systems,
# Nearest to ['been', 'may', 'to']: on,
# Nearest to ['are', 'into', 'there']: d,
# Nearest to ['he', 'so', 'these']: last,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: they,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: six,
# Nearest to ['known', 'state', 'if']: nine,
# Nearest to ['it', 's', 'during']: before,
# Average loss at step 92000: 3.181141
# Average loss at step 94000: 3.329527
# Average loss at step 96000: 3.343108
# Average loss at step 98000: 3.346109
# Average loss at step 100000: 3.351486
# Nearest to ['time', 'some', 'who']: bc,
# Nearest to ['only', 'see', 'th']: she,
# Nearest to ['of', 'will', 'is']: in,
# Nearest to ['four', 'states', 'called']: children,
# Nearest to ['often', 'for', 'and']: is,
# Nearest to ['his', 'history', 'at']: systems,
# Nearest to ['been', 'may', 'to']: within,
# Nearest to ['are', 'into', 'there']: d,
# Nearest to ['he', 'so', 'these']: last,
# Nearest to ['their', 'new', 'years']: can,
# Nearest to ['united', 'all', 'on']: they,
# Nearest to ['six', 'over', 'its']: her,
# Nearest to ['about', 'in', 'would']: their,
# Nearest to ['they', 'three', 'as']: nine,
# Nearest to ['known', 'state', 'if']: eight,
# Nearest to ['it', 's', 'during']: before,
